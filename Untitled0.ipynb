# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirudhPhophalia/Dog-vs-wolf/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub --quiet
import kagglehub
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
from sklearn.model_selection import train_test_split
import shutil

# %%
path = kagglehub.dataset_download("harishvutukuri/dogs-vs-wolves")
print("Dataset path:", path)
print("Contents:", os.listdir(path))
# Out:
# Dataset path: /kaggle/input/dogs-vs-wolves
# Contents: ['data']

# %%
data_dir = os.path.join(path, 'data')
print("Data dir contents:", os.listdir(data_dir))  # ['dogs', 'wolves']
# Out:
# Data dir contents: ['wolves', 'dogs']

# %%
split_base_dir = '/kaggle/working/split_data'  # Use working dir (writable)
train_dir = os.path.join(split_base_dir, 'train')
val_dir = os.path.join(split_base_dir, 'validation')

# %%
for label in ['dogs', 'wolves']:
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(val_dir, label), exist_ok=True)

# %%
for label in ['dogs', 'wolves']:
    src_dir = os.path.join(data_dir, label)
    images = os.listdir(src_dir)
    train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42)

    for img in train_imgs:
        shutil.copy(os.path.join(src_dir, img), os.path.join(train_dir, label, img))
    for img in val_imgs:
        shutil.copy(os.path.join(src_dir, img), os.path.join(val_dir, label, img))

# %%
print("Train dir contents:", os.listdir(train_dir))
print("Validation dir contents:", os.listdir(val_dir))
# Out:
# Train dir contents: ['dogs', 'wolves']
# Validation dir contents: ['dogs', 'wolves']

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, zoom_range=0.2, horizontal_flip=True)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 1600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=val_generator
)
# Out:
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 143s 3s/step - accuracy: 0.5940 - loss: 0.6695 - val_accuracy: 0.7150 - val_loss: 0.5463
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.6792 - loss: 0.6120 - val_accuracy: 0.7625 - val_loss: 0.5408
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 136s 3s/step - accuracy: 0.7336 - loss: 0.5549 - val_accuracy: 0.7575 - val_loss: 0.5399
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 139s 3s/step - accuracy: 0.7523 - loss: 0.5105 - val_accuracy: 0.7425 - val_loss: 0.5692
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 132s 3s/step - accuracy: 0.7732 - loss: 0.4847 - val_accuracy: 0.7700 - val_loss: 0.5174

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
